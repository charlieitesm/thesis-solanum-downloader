# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

pd.set_option('max_rows', 200)
pd.set_option('max_colwidth', 400)

# %% [markdown]
# # Loading of data

# %%
gbif_dataset_root_path = "/content/drive/MyDrive/Tesis/Datasets/GBif-Solanum_Mexico-0204003-200613084148143"

# %%
gbif_ocurrence = pd.read_csv(f"{gbif_dataset_root_path}/occurrence.txt",
                             sep="\t")

display(gbif_ocurrence.head(5))

print(gbif_ocurrence.shape)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (46,64,73,76,78,82,94,97,107,112,117,119,137,142,143,145,146,147,166,171,183,184,200,204,205,233,239,247,248) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        gbifID  abstract accessRights  ...  level2Name  level3Gid  level3Name
# 0  3043072125       NaN          NaN  ...         NaN        NaN         NaN
# 1  3037038568       NaN          NaN  ...         NaN        NaN         NaN
# 2  3037038512       NaN          NaN  ...         NaN        NaN         NaN
# 3  3037038465       NaN          NaN  ...         NaN        NaN         NaN
# 4  3037038462       NaN          NaN  ...         NaN        NaN         NaN
#
# [5 rows x 249 columns]
# (7471, 249)

# %%
gbif_multimedia = pd.read_csv(f"{gbif_dataset_root_path}/multimedia.txt",
                               sep="\t")

display(gbif_multimedia.head(5))

print(gbif_multimedia.shape)
# Out:
#        gbifID  ... rightsHolder
# 0  3043072125  ...          NaN
# 1  3037038568  ...          NaN
# 2  3037038512  ...          NaN
# 3  3037038465  ...          NaN
# 4  3037038462  ...          NaN
#
# [5 rows x 15 columns]
# (7857, 15)

# %% [markdown]
# # EDA
#
# Let's check whether all of the records have been identified.

# %% [markdown]
# ### Mexican species

# %%
mexican_species = ['Solanum Acerifolium',
 'Solanum Aculeatissimum',
 'Solanum Agrimonifolium',
 'Solanum Aligerum',
 'Solanum Americanum',
 'Solanum Angustifolium',
 'Solanum Aphyodendron',
 'Solanum Appendiculatum',
 'Solanum Atitlanum',
 'Solanum Aturense',
 'Solanum Aviculare',
 'Solanum Axillifolium',
 'Solanum Betaceum',
 'Solanum Bicorne',
 'Solanum Brevipedicellatum',
 'Solanum Bulbocastanum',
 'Solanum Campechiense',
 'Solanum Candidum',
 'Solanum Capsicoides',
 'Solanum Cardiophyllum',
 'Solanum Caripense',
 'Solanum Chiapasense',
 'Solanum Chrysotrichum',
 'Solanum Citrinum',
 'Solanum Citrullifolium',
 'Solanum Clarum',
 'Solanum Cobanense',
 'Solanum Cordovense',
 'Solanum Corymbosum',
 'Solanum Dasyanthum',
 'Solanum Dasyneuron',
 'Solanum Davisense',
 'Solanum Deflexum',
 'Solanum Demissum',
 'Solanum Dimidiatum',
 'Solanum Diphyllum',
 'Solanum Donianum',
 'Solanum Dulcamaroides',
 'Solanum Edinense',
 'Solanum Edmundoi',
 'Solanum Ehrenbergii',
 'Solanum Elaeagnifolium',
 'Solanum Erianthum',
 'Solanum Erythrotrichum',
 'Solanum Ferrugineum',
 'Solanum Fructo-Tecto',
 'Solanum Gardneri',
 'Solanum Glaucescens',
 'Solanum Grayi',
 'Solanum Guerreroense',
 'Solanum Hazenii',
 'Solanum Heterodoxum',
 'Solanum Hindsianum',
 'Solanum Hintonii',
 'Solanum Hirtum',
 'Solanum Hjertingii',
 'Solanum Hougasii',
 'Solanum Houstonii',
 'Solanum Ionidium',
 'Solanum Iopetalum',
 'Solanum Jamaicense',
 'Solanum Jamesii',
 'Solanum Johnstonii',
 'Solanum Knoblochii',
 'Solanum Lanceifolium',
 'Solanum Lanceolatum',
 'Solanum Laxum',
 'Solanum Lepidotum',
 'Solanum Lesteri',
 'Solanum Leucandrum',
 'Solanum Lignescens',
 'Solanum Lumholtzianum',
 'Solanum Lycopersicum',
 'Solanum Malacothrix',
 'Solanum Mammosum',
 'Solanum Marginatum',
 'Solanum Michoacanum',
 'Solanum Mitlense',
 'Solanum Morelliforme',
 'Solanum Muenscheri',
 'Solanum Muricatum',
 'Solanum Myriacanthum',
 'Solanum Narcoticosmum',
 'Solanum Nigrescens',
 'Solanum Nigricans',
 'Solanum Nitidibaccatum',
 'Solanum Nudum',
 'Solanum Oxycarpum',
 'Solanum Palmillae',
 'Solanum Pectinatum',
 'Solanum Phaseoloides',
 'Solanum Pinnatisectum',
 'Solanum Plumense',
 'Solanum Polyadenium',
 'Solanum Pruinosum',
 'Solanum Pseudocapsicum',
 'Solanum Pubigerum',
 'Solanum Pulverulentifolium',
 'Solanum Refractum',
 'Solanum Rojasianum',
 'Solanum Rostratum',
 'Solanum Rovirosanum',
 'Solanum Rudepannum',
 'Solanum Sambucinum',
 'Solanum Schenckii',
 'Solanum Schlechtendalianum',
 'Solanum Seaforthianum',
 'Solanum Setigeroides',
 'Solanum Sisymbriifolium',
 'Solanum Skutchii',
 'Solanum Sousae',
 'Solanum Splendens',
 'Solanum Stenophyllidium',
 'Solanum Stoloniferum',
 'Solanum Suaveolens',
 'Solanum Subvelutinum',
 'Solanum Tacanense',
 'Solanum Tampicense',
 'Solanum Tarnii',
 'Solanum Tenuipes',
 'Solanum Torvum',
 'Solanum Tribulosum',
 'Solanum Trifidum',
 'Solanum Triquetrum',
 'Solanum Triunfense',
 'Solanum Trizygum',
 'Solanum Tuerckheimii',
 'Solanum Umbellatum',
 'Solanum Umbelliferum',
 'Solanum Vallis-Mexici',
 'Solanum Verrucosum',
 'Solanum Volubile',
 'Solanum Wendlandii',
 'Solanum Wrightii']

# %% [markdown]
# ## Occurrences

# %%
gbif_ocurrence[["gbifID", "identifier"]].isna().sum()
# Out:
# gbifID         0
# identifier    26
# dtype: int64

# %%
gbif_ocurrence[gbif_ocurrence["species"].isna()].head(5)
# Out:
#         gbifID  abstract accessRights  ...    level2Name  level3Gid  level3Name
# 38  2884946514       NaN          NaN  ...  Nácori Chico        NaN         NaN
# 39  2884945527       NaN          NaN  ...  Nácori Chico        NaN         NaN
# 62  2610074828       NaN          NaN  ...           NaN        NaN         NaN
# 63  2610073904       NaN          NaN  ...           NaN        NaN         NaN
# 65  2610073241       NaN          NaN  ...           NaN        NaN         NaN
#
# [5 rows x 249 columns]

# %% [markdown]
# We'll hold off these 286 records for the test dataset. For now, let's figure out how many records have been identified.

# %%
gbif_ocurrence_identified = gbif_ocurrence[gbif_ocurrence["species"].isna() == False]
print(gbif_ocurrence_identified.shape)
# Out:
# (7185, 249)

# %% [markdown]
# Next, let's see how many unique species we have in the dataset, let's remember that as of 2021, there are 134 identified species in the Solanum Genus for Mexico.

# %%
unique_species = gbif_ocurrence_identified["species"].unique()
print("\n".join(sorted(unique_species)))
print(unique_species.shape)
# Out:
# Solanum acerifolium
# Solanum aculeatissimum
# Solanum aculeolatum
# Solanum adscendens
# Solanum aethiopicum
# Solanum agrimonifolium
# Solanum albidum
# Solanum aligerum
# Solanum americanum
# Solanum amictum
# Solanum angustifolium
# Solanum aphyodendron
# Solanum appendiculatum
# Solanum arboreum
# Solanum argentinum
# Solanum asperolanatum
# Solanum atropurpureum
# Solanum aturense
# Solanum axillifolium
# Solanum bahamense
# Solanum bejarense
# Solanum betaceum
# Solanum blodgettii
# Solanum bonariense
# Solanum brevipedicellatum
# Solanum bulbocastanum
# Solanum calvum
# Solanum campaniforme
# Solanum campechiense
# Solanum campylacanthum
# Solanum candidum
# Solanum capsicoides
# Solanum cardiophyllum
# Solanum caripense
# Solanum chacoense
# Solanum chiapasense
# Solanum chiapensis
# Solanum chrysotrichum
# Solanum citrinum
# Solanum citrullifolium
# Solanum clarum
# Solanum clokeyi
# Solanum cobanense
# Solanum colombianum
# Solanum conioides
# Solanum cordovense
# Solanum corymbosum
# Solanum cutervanum
# Solanum dasyadenium
# Solanum dasyanthum
# Solanum dasyneuron
# Solanum delilei
# Solanum demissum
# Solanum dichotomum
# Solanum dimidiatum
# Solanum diphyllum
# Solanum diversifolium
# Solanum donianum
# Solanum douglasii
# Solanum dulcamara
# Solanum dulcamaroides
# Solanum edinense
# Solanum ehrenbergii
# Solanum elaeagnifolium
# Solanum eleagnifolium
# Solanum ensifolium
# Solanum erianthum
# Solanum erythrotrichum
# Solanum extusviolascens
# Solanum ferrugineum
# Solanum flaccidum
# Solanum fructo-tecto
# Solanum fructu-tecto
# Solanum furcatum
# Solanum gardneri
# Solanum glaucescens
# Solanum glutinosum
# Solanum grayi
# Solanum guerreroense
# Solanum hayesii
# Solanum hazenii
# Solanum hernandesii
# Solanum heterodoxum
# Solanum hindsianum
# Solanum hintonii
# Solanum hirtum
# Solanum hjertingii
# Solanum hougasii
# Solanum houstonii
# Solanum interius
# Solanum ionidium
# Solanum iopetalum
# Solanum jamaicense
# Solanum jamesii
# Solanum johnstonii
# Solanum knoblochii
# Solanum lanceifolium
# Solanum lanceolatum
# Solanum laxum
# Solanum leiophyllum
# Solanum lepidotum
# Solanum leptopodum
# Solanum lesteri
# Solanum leucandrum
# Solanum leucocarpon
# Solanum leycesterianum
# Solanum lignescens
# Solanum linnaeanum
# Solanum longifolium
# Solanum lumholtzianum
# Solanum lycopersicum
# Solanum macranthemum
# Solanum macrocarpon
# Solanum macrotonum
# Solanum makrinii
# Solanum malacothrix
# Solanum malichense
# Solanum mammosum
# Solanum marginatum
# Solanum melissarum
# Solanum michoacanum
# Solanum microdontum
# Solanum microleprodes
# Solanum minensis
# Solanum mitlense
# Solanum morellifolium
# Solanum morelliforme
# Solanum muenscheri
# Solanum muricatum
# Solanum myriacanthum
# Solanum narcoticosmum
# Solanum nigrescens
# Solanum nigricans
# Solanum nigrum
# Solanum nitidum
# Solanum nudum
# Solanum nutans
# Solanum oblongifolium
# Solanum oxycarpum
# Solanum palmeri
# Solanum palmillae
# Solanum pectinatum
# Solanum phaseoloides
# Solanum pimpinellifolium
# Solanum pinnatisectum
# Solanum plumense
# Solanum polyadenium
# Solanum profundeincisum
# Solanum pruinosum
# Solanum pseudocapsicum
# Solanum pubigerum
# Solanum pulverulentifolium
# Solanum quadriflorum
# Solanum refractum
# Solanum robustum
# Solanum rojasianum
# Solanum rovirosanum
# Solanum rugosum
# Solanum salsum
# Solanum salviaefolium
# Solanum sambucinum
# Solanum sarmentosum
# Solanum scandens
# Solanum schenckii
# Solanum schlechtendalianum
# Solanum seaforthianum
# Solanum semidemissum
# Solanum sessile
# Solanum sessiliflorum
# Solanum sisymbriifolium
# Solanum skutchii
# Solanum sousae
# Solanum splendens
# Solanum stenophyllidium
# Solanum steyermarkii
# Solanum stoloniferum
# Solanum stramonifolium
# Solanum suaveolens
# Solanum subinerme
# Solanum subvelutinum
# Solanum sylvicola
# Solanum tacanense
# Solanum tampicense
# Solanum tarnii
# Solanum tenuilobatum
# Solanum tenuipes
# Solanum torvum
# Solanum tribulosum
# Solanum tricuspidatum
# Solanum tridynamum
# Solanum trifidum
# Solanum triquetrum
# Solanum triste
# Solanum triunfense
# Solanum trizygum
# Solanum tuberosum
# Solanum tuerckheimii
# Solanum umbellatum
# Solanum umbelliferum
# Solanum uncinellum
# Solanum uniflorum
# Solanum vallis-mexici
# Solanum verrucosum
# Solanum vestissimum
# Solanum viarum
# Solanum volubile
# Solanum wallacei
# Solanum wendlandii
# Solanum wrightii
# Solanum xanti
# (210,)

# %% [markdown]
# ### Missing species
#
# We have 210 species even though only 134 species have been identified for Mexico, this is happening because:
#
# 1. Some names for the species are invalid/outdated/have been replaced
# 1. Species are outright misidentified
#
# Let's first figure out if we have at least one record of the 134 valid species for Mexico.

# %%
missing_species = [sp for sp in mexican_species if sp.capitalize() not in unique_species]
print("\n".join(missing_species))
print(f"Missing species: {len(missing_species)}")
# Out:
# Solanum Atitlanum
# Solanum Aviculare
# Solanum Bicorne
# Solanum Davisense
# Solanum Deflexum
# Solanum Edmundoi
# Solanum Nitidibaccatum
# Solanum Rostratum
# Solanum Rudepannum
# Solanum Setigeroides
# Missing species: 10

# %% [markdown]
# ### Invalid species
#
# Let's get all of the invalid species in the dataset.

# %%
invalid_species = sorted([t for t in unique_species if t.title() not in mexican_species])

print("\n".join(invalid_species))
print(len(invalid_species))
# Out:
# Solanum aculeolatum
# Solanum adscendens
# Solanum aethiopicum
# Solanum albidum
# Solanum amictum
# Solanum arboreum
# Solanum argentinum
# Solanum asperolanatum
# Solanum atropurpureum
# Solanum bahamense
# Solanum bejarense
# Solanum blodgettii
# Solanum bonariense
# Solanum calvum
# Solanum campaniforme
# Solanum campylacanthum
# Solanum chacoense
# Solanum chiapensis
# Solanum clokeyi
# Solanum colombianum
# Solanum conioides
# Solanum cutervanum
# Solanum dasyadenium
# Solanum delilei
# Solanum dichotomum
# Solanum diversifolium
# Solanum douglasii
# Solanum dulcamara
# Solanum eleagnifolium
# Solanum ensifolium
# Solanum extusviolascens
# Solanum flaccidum
# Solanum fructu-tecto
# Solanum furcatum
# Solanum glutinosum
# Solanum hayesii
# Solanum hernandesii
# Solanum interius
# Solanum leiophyllum
# Solanum leptopodum
# Solanum leucocarpon
# Solanum leycesterianum
# Solanum linnaeanum
# Solanum longifolium
# Solanum macranthemum
# Solanum macrocarpon
# Solanum macrotonum
# Solanum makrinii
# Solanum malichense
# Solanum melissarum
# Solanum microdontum
# Solanum microleprodes
# Solanum minensis
# Solanum morellifolium
# Solanum nigrum
# Solanum nitidum
# Solanum nutans
# Solanum oblongifolium
# Solanum palmeri
# Solanum pimpinellifolium
# Solanum profundeincisum
# Solanum quadriflorum
# Solanum robustum
# Solanum rugosum
# Solanum salsum
# Solanum salviaefolium
# Solanum sarmentosum
# Solanum scandens
# Solanum semidemissum
# Solanum sessile
# Solanum sessiliflorum
# Solanum steyermarkii
# Solanum stramonifolium
# Solanum subinerme
# Solanum sylvicola
# Solanum tenuilobatum
# Solanum tricuspidatum
# Solanum tridynamum
# Solanum triste
# Solanum tuberosum
# Solanum uncinellum
# Solanum uniflorum
# Solanum vestissimum
# Solanum viarum
# Solanum wallacei
# Solanum xanti
# 86

# %% [markdown]
# Like we said, these species have either been renamed or they don't really belong to Mexico, so let's create a mapping of actual names to replace these with.
#
# For those species names that don't belong to Mexico, we'll remove the records from the dataset.

# %%
invalid_mappings = {
    "Solanum aculeolatum": "Solanum refractum",
    "Solanum amictum": "Solanum lanceolatum",
    "Solanum blodgettii": "Solanum donianum",
    "Solanum hernandesii": "Solanum ferrugineum",
    "Solanum palmeri": "Solanum umbelliferum",
    "Solanum tenuilobatum": "Solanum umbelliferum",
    "Solanum tridynamum": "Solanum houstonii",
    "Solanum xanti": "Solanum umbelliferum"
}

# %%
# Correct incorrect entries
gbif_ocurrence_identified["species"] = gbif_ocurrence_identified["species"].replace(invalid_mappings)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
mexican_species = [m.lower() for m in mexican_species]

gbif_ocurrence_identified["species"] = gbif_ocurrence_identified["species"].str.lower()

non_mexican_idx = gbif_ocurrence_identified[~gbif_ocurrence_identified["species"].isin(mexican_species)].index

gbif_ocurrence_identified.drop(non_mexican_idx, inplace=True)

gbif_ocurrence_identified.head(5)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#        gbifID  abstract accessRights  ...  level2Name  level3Gid  level3Name
# 0  3043072125       NaN          NaN  ...         NaN        NaN         NaN
# 1  3037038568       NaN          NaN  ...         NaN        NaN         NaN
# 2  3037038512       NaN          NaN  ...         NaN        NaN         NaN
# 3  3037038465       NaN          NaN  ...         NaN        NaN         NaN
# 4  3037038462       NaN          NaN  ...         NaN        NaN         NaN
#
# [5 rows x 249 columns]

# %%
print(gbif_ocurrence_identified.shape)
gbif_ocurrence_identified["species"].value_counts()
# Out:
# (6483, 249)
# solanum stoloniferum          397
# solanum lanceolatum           385
# solanum pubigerum             279
# solanum americanum            274
# solanum erianthum             217
# solanum angustifolium         214
# solanum nudum                 212
# solanum nigricans             202
# solanum houstonii             181
# solanum ferrugineum           179
# solanum elaeagnifolium        168
# solanum hindsianum            158
# solanum umbellatum            157
# solanum demissum              147
# solanum nigrescens            144
# solanum torvum                139
# solanum cardiophyllum         121
# solanum chrysotrichum         121
# solanum bulbocastanum         113
# solanum dulcamaroides         111
# solanum diphyllum             105
# solanum verrucosum            100
# solanum pseudocapsicum         95
# solanum schlechtendalianum     92
# solanum aphyodendron           87
# solanum grayi                  81
# solanum refractum              80
# solanum candidum               73
# solanum aligerum               70
# solanum heterodoxum            67
# solanum myriacanthum           64
# solanum umbelliferum           63
# solanum iopetalum              62
# solanum triquetrum             62
# solanum tampicense             60
# solanum polyadenium            58
# solanum hirtum                 58
# solanum lycopersicum           52
# solanum donianum               50
# solanum stenophyllidium        50
# solanum volubile               49
# solanum appendiculatum         48
# solanum campechiense           44
# solanum mitlense               41
# solanum trifidum               38
# solanum glaucescens            37
# solanum seaforthianum          34
# solanum citrullifolium         34
# solanum suaveolens             32
# solanum pinnatisectum          32
# solanum wendlandii             31
# solanum corymbosum             30
# solanum hjertingii             30
# solanum oxycarpum              28
# solanum morelliforme           27
# solanum splendens              27
# solanum hazenii                26
# solanum edinense               24
# solanum marginatum             23
# solanum cordovense             20
# solanum citrinum               19
# solanum laxum                  18
# solanum dasyanthum             18
# solanum rovirosanum            17
# solanum tenuipes               16
# solanum lanceifolium           16
# solanum gardneri               15
# solanum malacothrix            15
# solanum hougasii               14
# solanum agrimonifolium         14
# solanum lignescens             13
# solanum chiapasense            13
# solanum brevipedicellatum      12
# solanum schenckii              12
# solanum ionidium               12
# solanum sambucinum             11
# solanum ehrenbergii            11
# solanum lumholtzianum          10
# solanum jamesii                10
# solanum trizygum               10
# solanum sisymbriifolium         9
# solanum aturense                9
# solanum acerifolium             9
# solanum tarnii                  9
# solanum pulverulentifolium      8
# solanum pectinatum              8
# solanum johnstonii              8
# solanum lepidotum               8
# solanum tribulosum              7
# solanum mammosum                7
# solanum wrightii                7
# solanum subvelutinum            7
# solanum palmillae               7
# solanum tacanense               7
# solanum plumense                7
# solanum michoacanum             6
# solanum vallis-mexici           6
# solanum hintonii                6
# solanum betaceum                5
# solanum lesteri                 5
# solanum skutchii                5
# solanum fructo-tecto            5
# solanum dasyneuron              5
# solanum muricatum               4
# solanum dimidiatum              4
# solanum axillifolium            3
# solanum knoblochii              3
# solanum tuerckheimii            3
# solanum narcoticosmum           3
# solanum jamaicense              2
# solanum leucandrum              2
# solanum caripense               2
# solanum rojasianum              2
# solanum guerreroense            2
# solanum capsicoides             2
# solanum pruinosum               2
# solanum erythrotrichum          2
# solanum cobanense               2
# solanum phaseoloides            1
# solanum sousae                  1
# solanum triunfense              1
# solanum muenscheri              1
# solanum clarum                  1
# solanum aculeatissimum          1
# Name: species, dtype: int64

# %% [markdown]
# This is how many valid records we have for the species, but we still need to match them to valid multimedia values. Let's further reduce the data frame to just having the species so as to simplify it.

# %%
gbif_ocurrence_species = gbif_ocurrence_identified[["gbifID", "species"]]

gbif_ocurrence_species.head(5)
# Out:
#        gbifID                species
# 0  3043072125    solanum polyadenium
# 1  3037038568    solanum polyadenium
# 2  3037038512      solanum iopetalum
# 3  3037038465    solanum polyadenium
# 4  3037038462  solanum bulbocastanum

# %%
gbif_ocurrence_species.shape
# Out:
# (6483, 2)

# %% [markdown]
# ## Multimedia

# %% [markdown]
# Let's get the count of null values, taking special note of how the identifier column looks, this is the column where the URLs to the images are stored.

# %%
gbif_multimedia.isna().sum()
# Out:
# gbifID             0
# type               0
# format             0
# identifier        74
# references      6083
# title           6349
# description     7177
# source          7621
# audience        7857
# created         7731
# creator         4690
# contributor     7857
# publisher       7580
# license          993
# rightsHolder    2365
# dtype: int64

# %% [markdown]
# Let's merge the species dataframe with the multimedia dataframe on the gbifID

# %%
gbif_images = gbif_ocurrence_species.merge(gbif_multimedia[["gbifID", "identifier"]],
                                           on="gbifID",
                                           how="inner")

display(gbif_images.head(15))
print(gbif_images.shape)
# Out:
#         gbifID  ...                                                       identifier
# 0   3043072125  ...          http://herbarium.bioenv.gu.se/web/images/GB-0160204.jpg
# 1   3037038568  ...  http://www.jacq.org/image.php?filename=1405466&method=europeana
# 2   3037038512  ...  http://www.jacq.org/image.php?filename=1405505&method=europeana
# 3   3037038465  ...  http://www.jacq.org/image.php?filename=1405489&method=europeana
# 4   3037038462  ...  http://www.jacq.org/image.php?filename=1405470&method=europeana
# 5   3037038460  ...  http://www.jacq.org/image.php?filename=1405473&method=europeana
# 6   3037038451  ...  http://www.jacq.org/image.php?filename=1405463&method=europeana
# 7   3037038447  ...  http://www.jacq.org/image.php?filename=1405459&method=europeana
# 8   3037038436  ...  http://www.jacq.org/image.php?filename=1405472&method=europeana
# 9   3029004484  ...   http://www.jacq.org/image.php?filename=106883&method=europeana
# 10  3029004483  ...   http://www.jacq.org/image.php?filename=106884&method=europeana
# 11  3029004233  ...   http://www.jacq.org/image.php?filename=106880&method=europeana
# 12  3028991894  ...   http://www.jacq.org/image.php?filename=114166&method=europeana
# 13  3028991889  ...   http://www.jacq.org/image.php?filename=114164&method=europeana
# 14  3028991886  ...   http://www.jacq.org/image.php?filename=114167&method=europeana
#
# [15 rows x 3 columns]
# (6798, 3)

# %% [markdown]
# We need to check:
#
# 1. Why are we getting more records than on the dataframe for species? This is likely related to a given ID having more than one picture.
# 1. Check if there are null URLs, if there are we must remove them.

# %% [markdown]
# ### Null URL's

# %%
gbif_images.isna().sum()
# Out:
# gbifID         0
# species        0
# identifier    72
# dtype: int64

# %% [markdown]
# We have null URLs for some records, so let's remove them.

# %%
gbif_images = gbif_images[~gbif_images["identifier"].isna()]

display(gbif_images.isna().sum())
print(gbif_images.shape)
# Out:
# gbifID        0
# species       0
# identifier    0
# dtype: int64
# (6726, 3)

# %% [markdown]
# ### Check for multiple images
#
# As stated before, we found that after the merge we had more records with multimedia than with species, let's figure out why.
#
# This is most likely related to the fact that there might be multiple images for the same gbifID. This is fine and actually desirable.

# %%
gbif_images["gbifID"].value_counts()
# Out:
# 2270553226    3
# 1928390949    3
# 437486870     3
# 438301133     3
# 2270554494    3
#              ..
# 1929151101    1
# 1252678270    1
# 1929800320    1
# 2270605955    1
# 1927860707    1
# Name: gbifID, Length: 6411, dtype: int64

# %% [markdown]
# ### Duplicated URLs?

# %%
print(gbif_images.shape)
print(len(gbif_images["identifier"].unique()))
# Out:
# (6726, 3)
# 6723

# %%
gbif_images[gbif_images["identifier"].duplicated()]
# Out:
#           gbifID  ...                                                                                                  identifier
# 3224  1852134726  ...                                            http://n2t.net/ark:/65665/m3914d1a15-f03a-4382-986f-c069e84d688f
# 4320  1135479572  ...  https://www.nhm.ac.uk/services/media-store/asset/04efbe572d44a42aad325f1399ae41e5526e68b6/contents/preview
# 4467  1057022329  ...  https://www.nhm.ac.uk/services/media-store/asset/e3c379146b740c312a3cbd472db8a59764b7a49c/contents/preview
#
# [3 rows x 3 columns]

# %% [markdown]
# By inspecting the URLs, it turns out that a single picture contains more than one specimen, but given that the specimens are either of the same species or of the same Solanum section, we should leave them as they are in the dataset.

# %% [markdown]
# ## Final count
#
# We have a multimedia data frame, but after removing invalid species, removing records with no pictures, we must now figure out how many samples of each species we have and which species in Mexico we don't have a picture for.

# %%
display(gbif_images["species"].value_counts())
print(gbif_images.shape)
# Out:
# solanum stoloniferum          399
# solanum lanceolatum           394
# solanum pubigerum             280
# solanum americanum            275
# solanum angustifolium         219
# solanum erianthum             216
# solanum nudum                 214
# solanum nigricans             210
# solanum houstonii             201
# solanum ferrugineum           183
# solanum elaeagnifolium        167
# solanum hindsianum            165
# solanum umbellatum            159
# solanum nigrescens            149
# solanum demissum              148
# solanum torvum                140
# solanum cardiophyllum         130
# solanum chrysotrichum         129
# solanum bulbocastanum         114
# solanum dulcamaroides         112
# solanum diphyllum             106
# solanum pseudocapsicum        105
# solanum verrucosum             97
# solanum schlechtendalianum     93
# solanum aphyodendron           89
# solanum refractum              87
# solanum grayi                  84
# solanum candidum               82
# solanum aligerum               73
# solanum heterodoxum            71
# solanum umbelliferum           68
# solanum myriacanthum           67
# solanum tampicense             67
# solanum polyadenium            65
# solanum triquetrum             62
# solanum iopetalum              62
# solanum hirtum                 61
# solanum donianum               51
# solanum stenophyllidium        51
# solanum lycopersicum           50
# solanum volubile               50
# solanum appendiculatum         47
# solanum mitlense               44
# solanum campechiense           44
# solanum citrullifolium         41
# solanum glaucescens            40
# solanum seaforthianum          38
# solanum splendens              38
# solanum trifidum               37
# solanum pinnatisectum          33
# solanum hjertingii             33
# solanum suaveolens             32
# solanum wendlandii             32
# solanum corymbosum             30
# solanum hazenii                28
# solanum oxycarpum              28
# solanum citrinum               27
# solanum morelliforme           26
# solanum cordovense             26
# solanum edinense               24
# solanum marginatum             24
# solanum hougasii               20
# solanum dasyanthum             20
# solanum chiapasense            20
# solanum lanceifolium           19
# solanum laxum                  18
# solanum malacothrix            17
# solanum rovirosanum            17
# solanum tenuipes               17
# solanum gardneri               15
# solanum agrimonifolium         15
# solanum ionidium               14
# solanum lignescens             14
# solanum trizygum               13
# solanum schenckii              13
# solanum brevipedicellatum      12
# solanum ehrenbergii            11
# solanum sambucinum             11
# solanum jamesii                11
# solanum lumholtzianum          10
# solanum acerifolium             9
# solanum aturense                9
# solanum pectinatum              9
# solanum johnstonii              9
# solanum tarnii                  9
# solanum tribulosum              9
# solanum sisymbriifolium         9
# solanum tacanense               8
# solanum hintonii                8
# solanum pulverulentifolium      8
# solanum plumense                8
# solanum palmillae               8
# solanum lepidotum               8
# solanum wrightii                7
# solanum subvelutinum            7
# solanum dasyneuron              7
# solanum mammosum                7
# solanum michoacanum             6
# solanum vallis-mexici           6
# solanum knoblochii              6
# solanum betaceum                5
# solanum skutchii                5
# solanum axillifolium            5
# solanum fructo-tecto            5
# solanum lesteri                 5
# solanum muricatum               4
# solanum dimidiatum              4
# solanum tuerckheimii            3
# solanum cobanense               3
# solanum narcoticosmum           3
# solanum aculeatissimum          2
# solanum jamaicense              2
# solanum caripense               2
# solanum rojasianum              2
# solanum guerreroense            2
# solanum capsicoides             2
# solanum pruinosum               2
# solanum erythrotrichum          2
# solanum leucandrum              2
# solanum phaseoloides            1
# solanum sousae                  1
# solanum triunfense              1
# solanum muenscheri              1
# solanum clarum                  1
# Name: species, dtype: int64
# (6726, 3)

# %% [markdown]
# ### We are missing these mexican species

# %%
missing_photo_samples = sorted([ms for ms in mexican_species if ms not in gbif_images["species"].unique()])

print("\n".join(missing_photo_samples))
print(len(missing_photo_samples))
# Out:
# solanum atitlanum
# solanum aviculare
# solanum bicorne
# solanum davisense
# solanum deflexum
# solanum edmundoi
# solanum nitidibaccatum
# solanum rostratum
# solanum rudepannum
# solanum setigeroides
# 10

# %% [markdown]
# ## Adding the section to the dataframe

# %%
sections = pd.read_csv("/content/drive/MyDrive/Tesis/Bibliografía/Secciones_Solanum.csv",
                       encoding="ISO-8859-1")

sections["Section"] = sections["Section"].apply(lambda sec: sec.split()[1].lower())

sections["Species"] = sections["Species"].apply(lambda sp: " ".join((sp.split()[0].lower(), sp.split()[1].lower())))

def fusion_species(series: pd.Series):
    unique_species = sorted(set(series))
    return ", ".join(unique_species)

species_by_section = sections.groupby('Section').agg({'Species':fusion_species}).reset_index()
display(species_by_section)
# Out:
#             Section                                                                                                                                                                                                                                                                                                                                                                                                          Species
# 0      acanthophora                                                                                                                                                                                                                                                                                                         solanum acerifolium, solanum aculeatissimum, solanum capsicoides, solanum mammosum, solanum myriacanthum
# 1   anarrhichomenum                                                                                                                                                                                                                                                                                                              solanum appendiculatum, solanum ionidium, solanum skutchii, solanum subvelutinum, solanum tacanense
# 2     archaesolanum                                                                                                                                                                                                                                                                                                                                                                                                solanum aviculare
# 3        basarthrum                                                                                                                                                                                                                                                                                                                                                         solanum caripense, solanum muricatum, solanum suaveolens
# 4      brevantherum                                                                                                                                                 solanum atitlanum, solanum axillifolium, solanum brevipedicellatum, solanum chiapasense, solanum cordovense, solanum erianthum, solanum hazenii, solanum lepidotum, solanum plumense, solanum pulverulentifolium, solanum schlechtendalianum, solanum umbellatum
# 5          crinitum                                                                                                                                                                                                                                                                                                                                                                               solanum mitlense, solanum wrightii
# 6         dulcamara                                                                                                                                                                                                                                                                        solanum corymbosum, solanum dulcamaroides, solanum laxum, solanum seaforthianum, solanum sousae, solanum triquetrum, solanum umbelliferum
# 7    erythrotrichum                                                                                                                                                                                                                                                                                                                                                                                           solanum erythrotrichum
# 8     gonatotrichum                                                                                                                                                                                                                                                                                                                                                                             solanum deflexum, solanum lignescens
# 9      herposolanum                                                                                                                                                                                                                                                                             solanum bicorne, solanum cobanense, solanum edmundoi, solanum glaucescens, solanum refractum, solanum triunfense, solanum wendlandii
# 10    herpystrichum                                                                                                                                                                                                                                                                                                                                                                                             solanum phaseoloides
# 11       holophylla                                                                                                                         solanum aligerum, solanum aphyodendron, solanum dasyneuron, solanum diphyllum, solanum malacothrix, solanum muenscheri, solanum narcoticosmum, solanum nigricans, solanum nudum, solanum palmillae, solanum pseudocapsicum, solanum pubigerum, solanum rovirosanum, solanum tuerckheimii
# 12       lasiocarpa                                                                                                                                                                                                                                                                                                                                                             solanum candidum, solanum hirtum, solanum pectinatum
# 13     lycopersicon                                                                                                                                                                                                                                                                                                                                                                                             solanum lycopersicum
# 14        melongena  solanum angustifolium, solanum campechiense, solanum citrinum, solanum citrullifolium, solanum davisense, solanum dimidiatum, solanum elaeagnifolium, solanum fructo-tecto, solanum grayi, solanum heterodoxum, solanum hindsianum, solanum houstonii, solanum johnstonii, solanum knoblochii, solanum leucandrum, solanum lumholtzianum, solanum marginatum, solanum rostratum, solanum setigeroides, solan...
# 15      micracantha                                                                                                                                                                                                                                                                                                                 solanum aturense, solanum jamaicense, solanum lanceifolium, solanum tampicense, solanum volubile
# 16      pachyphylla                                                                                                                                                                                                                                                                                                                                                          solanum betaceum, solanum rojasianum, solanum splendens
# 17      periscariae                                                                                                                                                                                                                                                                                                                                                                                                 solanum gardneri
# 18           petota  solanum agrimonifolium, solanum bulbocastanum, solanum cardiophyllum, solanum clarum, solanum demissum, solanum edinense, solanum ehrenbergii, solanum guerreroense, solanum hintonii, solanum hjertingii, solanum hougasii, solanum iopetalum, solanum jamesii, solanum lesteri, solanum michoacanum, solanum morelliforme, solanum oxycarpum, solanum pinnatisectum, solanum polyadenium, solanum sambucin...
# 19        pteroidea                                                                                                                                                                                                                                                                                                                                                                                                 solanum trizygum
# 20          solanum                                                                                                                                                                                                                                                                                                                                solanum americanum, solanum nigrescens, solanum nitidibaccatum, solanum pruinosum
# 21            torva                                                                                                                                                                                                                                                                        solanum chrysotrichum, solanum dasyanthum, solanum donianum, solanum ferrugineum, solanum lanceolatum, solanum rudepannum, solanum torvum

# %%
def determine_section(row: pd.Series, species_by_section: pd.DataFrame) -> str:

    specimen_species = row["species"]
    
    return sections[sections["Species"] == specimen_species]["Section"].to_string(index=False).strip()


gbif_images["section"] = gbif_images.apply(lambda row: determine_section(row, species_by_section), axis=1)

# %%
display(gbif_images.isna().sum())
display(gbif_images.head(20))
# Out:
# gbifID        0
# species       0
# identifier    0
# section       0
# dtype: int64
#         gbifID  ...     section
# 0   3043072125  ...      petota
# 1   3037038568  ...      petota
# 2   3037038512  ...      petota
# 3   3037038465  ...      petota
# 4   3037038462  ...      petota
# 5   3037038460  ...      petota
# 6   3037038451  ...      petota
# 7   3037038447  ...      petota
# 8   3037038436  ...      petota
# 9   3029004484  ...      petota
# 10  3029004483  ...      petota
# 11  3029004233  ...      petota
# 12  3028991894  ...      petota
# 13  3028991889  ...   melongena
# 14  3028991886  ...  holophylla
# 15  3028990407  ...  holophylla
# 16  2989908213  ...   melongena
# 17  2981282905  ...      petota
# 18  2981280570  ...      petota
# 19  2981280286  ...  holophylla
#
# [20 rows x 4 columns]

# %% [markdown]
# ## How many samples per section do we have?

# %%
display(gbif_images["section"].value_counts())
# Out:
# petota             1365
# holophylla         1133
# melongena          1114
# torva               917
# brevantherum        583
# solanum             426
# dulcamara           329
# herposolanum        163
# lasiocarpa          152
# micracantha         147
# acanthophora         87
# anarrhichomenum      81
# crinitum             51
# lycopersicon         50
# pachyphylla          45
# basarthrum           38
# periscariae          15
# gonatotrichum        14
# pteroidea            13
# erythrotrichum        2
# herpystrichum         1
# Name: section, dtype: int64

# %% [markdown]
# ## What sections are we missing?

# %%
print("\n".join([s for s in sections["Section"].unique() if s not in gbif_images["section"].unique()]))
# Out:
# archaesolanum

# %% [markdown]
# This is a really rare section, so it sounds reasonable that there are no speciments.
#
# With this we can see that even though we don't have a sample of each specimen, we do have at least one specimen of each section.

# %% [markdown]
# ## Store results to disk

# %%
# gbif_images = pd.read_csv(f"{gbif_dataset_root_path}/gbif_images_by_sections.csv")

# %%
# Rename the identifier column
gbif_images = gbif_images.rename(columns={
    "gbifID": "id",
    'identifier': 'url'
    })

gbif_images["species"] = gbif_images["species"].apply(lambda sp: sp.split()[1].lower())

gbif_images["source"] = "gbif"

gbif_images.head(3)
# Out:
#            id      species  ... section source
# 0  3043072125  polyadenium  ...  petota   gbif
# 1  3037038568  polyadenium  ...  petota   gbif
# 2  3037038512    iopetalum  ...  petota   gbif
#
# [3 rows x 5 columns]

# %%
gbif_images.to_csv(f"{gbif_dataset_root_path}/gbif_images_by_sections.csv",
                   index=False)

# %% [markdown]
# # Downloading of the images TBD
#
# For this part, we need to use the data frame of images that we just built and go image by image attempting to download it. Images are linked by their URLs in two different ways:
#
# 1. As a direct link to the image file
# 1. As an HTML with a the image file linked in the `src` property of its `<img>` tag.
#
# We should detect which type has been served to us so that we can act appropriately.
#
# Images should be stored in a `<section>/` folder and have its file name following this template: `gbif_<gbif_id>_<section>_<species>.jpg|png|gif`.
#
# If a file couldn't be successfully pulled, the record should be put as it is in a new Data Frame for files markes as problematic and its final shape should be output to a new csv file called `gbif_failed_records.csv`.
#
# Prior to downloading, we should check if the file we intend to download has already been downloaded or not. If a file already exists, we should check if there are more files to download for the same specimen, if there are, an index should be suffixed at the end of the filename, if not, no index should be added.

# %%
gbif_images.read_csv(f"{gbif_dataset_root_path}/gbif_images_by_sections.csv")
output_path = ""

# %%
for index, row in df.iterrows():
    print(row['c1'], row['c2'])
